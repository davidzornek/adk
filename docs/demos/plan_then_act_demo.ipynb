# %% [markdown]
# # Plan-Then-Act Demo: Web Search + Calculator
#
# This notebook drives `adk.demos.plan_then_act_demo.DemoPlanThenActAgent`, a concrete
# `PlannerExecutorBase` subclass built on the **plan-then-act** pattern from `adk.planner_executor`.
# It wires two real, heterogeneous tools behind fault-tolerant executor boundaries:
#
# - **`web_search`** — a live Tavily web search
# - **`calculate`** — a sandboxed arithmetic evaluator (no `eval()`; an AST allowlist, since the
#   expression can be LLM-influenced input)
#
# The agent's own code lives in `src/adk/demos/plan_then_act_demo.py` — this notebook imports it
# and walks through what it does, rather than redefining any of the logic here.
#
# **This demo is intentionally contrived.** The task below is small and predictable on purpose,
# so the thing on display is the *plumbing* — real tool calls crossing two heterogeneous
# executors, dependency-wave scheduling, degraded-mode handling, the plan-then-act topology
# itself, all running against live APIs instead of fakes. It is not meant to show off planning
# sophistication or anything worth calling reasoning ability; later examples, built on the same
# base classes, will lean into tasks that actually exercise that.

# %% [markdown]
# ## Setup
#
# Requires two API keys:
#
# - `ANTHROPIC_API_KEY` — https://console.anthropic.com/
# - `TAVILY_API_KEY` — https://tavily.com/
#
# Copy `.env.example` (repo root) to `.env` and paste your keys in there — `load_dotenv()`
# below loads it into this process. `.env` is gitignored, so real keys never get committed.
# `adk.anthropic_client.get_anthropic_client()` and `adk.search_client.get_search_client()`
# raise a clear `RuntimeError` if either key is still missing.

# %%
import os

from dotenv import load_dotenv

load_dotenv()

for key in ("ANTHROPIC_API_KEY", "TAVILY_API_KEY"):
    print(f"{key}: {'set' if os.environ.get(key) else 'MISSING'}")
# Out:
# ANTHROPIC_API_KEY: set
# TAVILY_API_KEY: set

# %% [markdown]
# ## The tools
#
# Both tools share one signature — `(args: dict, ctx: dict) -> Any` — the contract
# `DegradedModeExecutor` expects: plain callables, agnostic to how they're implemented.

# %%
from adk.demos.plan_then_act_demo import (
    DEFAULT_TASK,
    DemoPlanThenActAgent,
    calculate,
    web_search,
)

# %% [markdown]
# ### `calculate` — safe by construction
#
# `calculate` parses the expression with `ast.parse(..., mode="eval")` and walks the tree,
# allowing only numeric constants, `+ - * / // % **`, and unary `+ -`. Anything else — a `Name`,
# a `Call`, an `Attribute` — is rejected. Try a normal expression, then an injection attempt:

# %%
print(calculate({"expression": "68000000 + 84000000"}, {}))

try:
    calculate({"expression": "__import__('os').system('echo pwned')"}, {})
except ValueError as exc:
    print(f"blocked: {exc}")
# Out:
# {'expression': '68000000 + 84000000', 'result': 152000000}
# blocked: unsupported expression element: Call(func=Attribute(value=Call(func=Name(id='__import__', ctx=Load()), args=[Constant(value='os')], keywords=[]), attr='system', ctx=Load()), args=[Constant(value='echo pwned')], keywords=[])

# %% [markdown]
# ### `web_search` — live Tavily search
#
# Calls `get_search_client().search(...)` and maps the top results down to
# `{"title", "url", "snippet"}`. This cell makes a real API call.

# %%
result = web_search({"query": "current population of France"}, {})
result
# Out:
# {'query': 'current population of France',
#  'results': [{'title': 'France Population (2026)',
#    'url': 'https://www.worldometers.info/world-population/france-population',
#    'snippet': "The current population of France is 66,759,641 as of Saturday, July 25, 2026, based on Worldometer's elaboration of the latest United Nations data1.\n France 2026 population is estimated at 66,746,401 people at mid-year.\n France population is equivalent to 0.8% of the total world population.\n France ranks number 23 in the list of countries (and dependencies) by population.\n The population density in France is 122 per Km² (316 people per mi²). [...] The total land area is 547,557 Km² (211,413 sq. miles).\n 83% of the population is urban (55,375,164 people in 2026)\n The median age in France is 42.5 years. [...] ### Notes\n\nThe France Population (Live) counter shows a continuously updated estimate of the current population of France delivered by Worldometer's RTS algorithm, which processes data collected from the United Nations Population Division.\n\nThe Population of France (1950 - 2026) chart plots the total population count as of July 1 of each year, from 1950 to 2026."},
#   {'title': 'France Population (1950-2026)',
#    'url': 'https://www.macrotrends.net/global-metrics/countries/fra/france/population',
#    'snippet': '✖\n\nImage 1: Macrotrends Logo\n\n## France Population (1950-2026)\n\nPopulationEconomyTradeHealthEducationDevelopmentLabor ForceEnvironmentCrimeImmigrationOther\n\nPopulationGrowth RateDensityUrbanRuralLife ExpectancyBirth RateDeath RateInfant Mortality RateFertility Rate\n\n##### Total current population for France in 2026 is 65,121,251, a 0.18% increase from 2025. [...] Total population for France in 2025 was 65,003,384, a 0.19% increase from 2024.\n   Total population for France in 2024 was 64,881,830, a 0.19% increase from 2023.\n   Total population for France in 2023 was 64,756,584, a 0.2% increase from 2022. [...] | Germany | 83,134,876 |\n| Tanzania | 73,462,459 |\n| Thailand | 72,005,720 |\n| United Kingdom | 68,393,799 |\n| France | 65,121,251 |\n| South Africa | 62,305,039 |\n| Kenya | 58,457,378 |\n| Italy | 58,334,490 |\n| Myanmar | 55,695,986 |\n| Colombia | 52,902,741 |\n| Uganda | 52,667,779 |\n| Sudan | 51,878,825 |\n| South Korea | 51,630,817 |\n| Iraq | 48,583,520 |\n| Algeria | 47,538,087 |\n| Spain | 47,360,679 |\n| Argentina | 46,613,495 |\n| Afghanistan | 45,667,550 |\n| Angola | 40,099,526 |'},
#   {'title': "France's population to peak at 69.8M in 2037 before steady decline, stats agency says",
#    'url': 'https://www.aa.com.tr/en/europe/frances-population-to-peak-at-698m-in-2037-before-steady-decline-stats-agency-says/3960552',
#    'snippet': "ISTANBUL\n\nFrance's population is expected to reach a peak of 69.8 million people in 2037 before entering a period of gradual decline, according to new projections released on Monday by the country's National Institute of Statistics and Economic Studies (INSEE).\n\nIf current demographic trends continue, the population would fall to 65.9 million by 2070, compared with 69.1 million inhabitants in 2026, the statistics agency said. [...] logo\n\nlogo\n\nEurope\n\n# France's population to peak at 69.8M in 2037 before steady decline, stats agency says\n\nIf current demographic trends continue, population will fall to 65.9M by 2070, compared with 69.1M inhabitants in 2026, according to National Institute of Statistics and Economic Studies\n\nNecva Tastan Sevinc\n\n08 June 2026•Update: 08 June 2026\n\nContent media\n\nISTANBUL [...] While population decline remains uncertain and will depend largely on future fertility and migration trends, INSEE said population aging is inevitable due to longer life expectancy and demographic changes already underway.\n\nDepending on how fertility and migration evolve, France's population in 2070 could range between 61 million and 71 million people, the agency added.\n\nFrance's population to peak at 69.8M in 2037 before steady decline, stats agency says\n\nnews\\_share"}]}

# %% [markdown]
# ## Why plan-then-act (and its tradeoff)
#
# `build_plan_then_act_graph` compiles: `produce_plan -> execute_plan -> draft_response -> END`.
# The planner produces the **entire** plan up front, before any tool has run — there's no
# mechanism to feed one step's tool output into a later step's arguments. Compare that to the
# *interleaved* pattern (`build_planner_executor_graph`), which re-plans after every tool call and
# so *can* thread live results forward.
#
# The demo task below — "look up the current population of France and Germany, then calculate
# their combined population" — is chosen for how legible it makes the *orchestration*, not for
# planning difficulty:
#
# - Two independent `search` steps run concurrently (no `depends_on` between them).
# - The `calc` step's `depends_on` orders it after both searches, exercising the execution
#   coordinator's dependency-wave scheduling.
# - The planner has to correctly route each step to the executor that owns its tool.
#
# That's routing and ordering, not reasoning about the task itself. What the demo does *not* do
# is compute the sum from the live search numbers — the `calculate` step's expression is filled
# in from the planner LLM's own knowledge at plan time. That's an intentional pattern tradeoff,
# not a bug: true tool-output-to-tool-input chaining is the interleaved pattern's job, not
# plan-then-act's. A future example can pick a task where that tradeoff actually bites.

# %% [markdown]
# ## Building the agent
#
# `DemoPlanThenActAgent._build_graph()` assembles:
#
# - **planner** — `build_plan_then_act_planner(client, model=, system_prompt=PLANNER_SYSTEM_PROMPT)`,
#   an `AnthropicRunnable` forced to call the `output_plan` tool so its response always parses into
#   a `PlanThenActArtifact`.
# - **executors** — `{"search": DegradedModeExecutor(...), "calc": DegradedModeExecutor(...)}`,
#   each wrapping one tool and degrading gracefully (instead of failing the whole run) if its tool
#   raises.
# - **drafter** — a plain `AnthropicRunnable` that synthesizes the accumulated observations into a
#   final answer.
# - **config** — `PlannerExecutorConfig(tools_by_executor={"search": ("web_search",), "calc":
#   ("calculate",)})`, the routing fallback the execution coordinator uses if a step's
#   `executor_id` doesn't directly match a key in `executors`.
#
# Constructing the agent builds and compiles the graph immediately (`PlannerExecutorBase.__init__`
# calls `_build_graph()`), so this cell needs a valid `ANTHROPIC_API_KEY` to create the underlying
# client.

# %%
agent = DemoPlanThenActAgent()
agent.get_compiled_graph().get_graph().print_ascii()
# Out:
#   +-----------+
#   | __start__ |
#   +-----------+
#          *
#          *
#          *
#  +--------------+
#  | produce_plan |
#  +--------------+
#          *
#          *
#          *
#  +--------------+
#  | execute_plan |
#  +--------------+
#          *
#          *
#          *
# +----------------+
# | draft_response |
# +----------------+
#          *
#          *
#          *
#     +---------+
#     | __end__ |
#     +---------+

# %% [markdown]
# ## Running the demo task
#
# `.invoke()` maps `{"task", "context"}` to initial graph state, runs the compiled graph, and
# attaches an `invoke_trace` (run id, variant, prompt manifest) to the output.

# %%
out = agent.invoke({"task": DEFAULT_TASK, "context": {}})
print(f"Task: {DEFAULT_TASK}")
# Out:
# Task: Look up the current population of France and Germany, then calculate their combined population.

# %% [markdown]
# ### Authorized plan
#
# The steps the planner produced, in order, with their dependencies:

# %%
def print_plan(steps):
    for i, step in enumerate(steps):
        deps = step.depends_on
        print(f"{i}. [{step.executor_id}] {step.tool_name}({step.tool_args}) depends_on={deps}")


print_plan(out["authorized_steps"])
# Out:
# 0. [search] web_search({'query': 'current population of France 2024'}) depends_on=None
# 1. [search] web_search({'query': 'current population of Germany 2024'}) depends_on=None
# 2. [calc] calculate({'expression': '68000000 + 84000000'}) depends_on=[0, 1]

# %% [markdown]
# ### Executed steps
#
# What each executor actually did (`status` is `"ok"` or `"degraded"`):

# %%
for step in out["executed_steps"]:
    print(step)
# Out:
# {'executor_id': 'search', 'tool': 'web_search', 'status': 'ok', 'payload': {'query': 'current population of France 2024', 'results': [{'title': 'France Population (1950-2026)', 'url': 'https://www.macrotrends.net/global-metrics/countries/fra/france/population', 'snippet': 'Total population for France in 2025 was 65,003,384, a 0.19% increase from 2024.\n   Total population for France in 2024 was 64,881,830, a 0.19% increase from 2023.\n   Total population for France in 2023 was 64,756,584, a 0.2% increase from 2022. [...] ✖\n\nImage 1: Macrotrends Logo\n\n## France Population (1950-2026)\n\nPopulationEconomyTradeHealthEducationDevelopmentLabor ForceEnvironmentCrimeImmigrationOther\n\nPopulationGrowth RateDensityUrbanRuralLife ExpectancyBirth RateDeath RateInfant Mortality RateFertility Rate\n\n##### Total current population for France in 2026 is 65,121,251, a 0.18% increase from 2025.'}, {'title': 'Demographics of France', 'url': 'https://en.wikipedia.org/wiki/Demographics_of_France', 'snippet': '| 2019 | 65,096,768 | +139,849 |\n| 2020 | 65,269,154 | +227,847 |\n| 2021 (p) | 65,505,213 | +193,000 |\n| 2022 (p) | 65,721,831 | +193,000 |\n| 2023 (p) | 65,925,961 | +193,000 |\n| 2024 (p) | 66,142,961 | +152,000 | [...] | 2022 | 65,846,255 | 686,654 | 658,434 | 28,130 | 10.4 | 9.9 | 0.5 | 2.6 | 1.757 | 3.9 | 79.4 | 85.2 |\n| 2023 | 66,165,815 | 639,533 | 623,959 | 15,574 | 9.7 | 9.5 | 0.2 | 2.4 | 1.639 | 80.0 | 85.6 |\n| 2024 | 66,379,851 | 626,776 | 627,513 | –737 | 9.5 | 9.5 | –0.0 | 2.4 | 1.59 | 80.1 | 85.7 |\n| 2025 | 66,578,547 | 610,185 | 631,145 | –20,960 | 9.2 | 9.5 | –0.3 | 3.3 | 1.56 |\n| 2026 | 66,792,845 | [...] The national birth rate, after dropping for a time, began to rebound in the 1990s, and the country\'s fertility rate was close to the replacement level until about 2014. According to a 2006 INSEE study, the natural increase was close to 300,000 people a year, a level that had "not been reached in more than thirty years." With a total fertility rate of 1.59 (for France métropolitaine) in 2024, France remains one of the above-average fertile countries in the European Union, but it is now far from'}, {'title': 'France Population (2026)', 'url': 'https://www.worldometers.info/world-population/france-population', 'snippet': "| 2024 | 66,548,530 | 0.17% | 109,708 | 90,527 | 42.1 | 1.64 | 122 | 82.1% | 54,661,663 | 0.82% | 8,161,972,572 | 23 |\n| 2023 | 66,438,822 | 0.24% | 161,413 | 91,862 | 41.8 | 1.64 | 121 | 81.7% | 54,303,895 | 0.82% | 8,091,734,930 | 23 |\n| 2022 | 66,277,409 | 0.28% | 186,066 | 179,377 | 41.6 | 1.76 | 121 | 81.4% | 53,944,675 | 0.83% | 8,021,407,192 | 22 |\n| 2020 | 65,905,277 | 0.3% | 197,788 | 145,593 | 41.3 | 1.78 | 120 | 80.7% | 53,217,966 | 0.84% | 7,887,001,292 | 22 | [...] The current population of France is 66,759,641 as of Saturday, July 25, 2026, based on Worldometer's elaboration of the latest United Nations data1.\n France 2026 population is estimated at 66,746,401 people at mid-year.\n France population is equivalent to 0.8% of the total world population.\n France ranks number 23 in the list of countries (and dependencies) by population.\n The population density in France is 122 per Km² (316 people per mi²). [...] Source: Worldometer (www.Worldometers.info)\n\nElaboration of data by United Nations, Department of Economic and Social Affairs, Population Division. World Population Prospects: The 2024 Revision. (Medium-fertility variant).\n\n# France Demographics (2026)\n\nMain Page: Demographics of France\n\nLife Expectancy\n\n83.7 years\n\n(life expectancy at birth, both sexes)\n\nView by sex and historical chart\n\nInfant Mortality Rate\n\n3.0\n\n(infant deaths per 1,000 live births)\n\nView historical chart"}]}}
# {'executor_id': 'search', 'tool': 'web_search', 'status': 'ok', 'payload': {'query': 'current population of Germany 2024', 'results': [{'title': 'Demographics of Germany', 'url': 'https://en.wikipedia.org/wiki/Demographics_of_Germany', 'snippet': '| 2024 | 82,769,000 | 100.00 | 63,554,000 | 76.78 | 3,776,000 | 4.56 | 15,439,000 | 18.65 | [...] | Change 2023 to 2024 |\n ---  --- |\n| 31 December 2022 | 31 December 2023 | 31 December 2024 |\n| Total | 11,495,135 | 12,108,988 | 12,392,275 | 283,287 Increase |\n| 1 | Turkey | 1,323,571 | 1,391,800 | 1,402,783 | 10,983 Increase |\n| 2 | Ukraine | 863,335 | 974,322 | 1,085,298 | 110,976 Increase |\n| 3 | Syria | 829,143 | 879,823 | 889,482 | 9,659 Increase |\n| 4 | European Union Romania | 753,056 | 776,424 | 771,276 | −5,148 Decrease | [...] | 2023 | 83,456,045 | 692,989 | 1,028,206 | −335,217 | 8.3 | 12.3 | −4.0 | 8.1 | 1.38 | 1.41 | 1.33 |\n| 2024 | 83,577,140 | 677,117 | 1,007,758 | −330,641 | 8.1 | 12.1 | −4.0 | 5.4 | 1.35 | 1.38 | 1.27 |\n| 2025 | 83,467,117 | 654,241 | 1,006,588 | –352,079 | 7.8 | 12.1 | –4.3 | 2.9 | 1.32 | 1.34 | 1.22 |'}, {'title': 'Germany Population (1950-2026)', 'url': 'https://www.macrotrends.net/global-metrics/countries/deu/germany/population', 'snippet': 'Total population for Germany in 2025 was 83,199,069, a 0.06% decline from 2024.\n   Total population for Germany in 2024 was 83,252,474, a 0.05% decline from 2023.\n   Total population for Germany in 2023 was 83,294,633, a 0.09% decline from 2022. [...] ✖\n\nImage 1: Macrotrends Logo\n\n## Germany Population (1950-2026)\n\nPopulationEconomyTradeHealthEducationDevelopmentLabor ForceEnvironmentCrimeImmigrationOther\n\nPopulationGrowth RateDensityUrbanRuralLife ExpectancyBirth RateDeath RateInfant Mortality RateFertility Rate\n\n##### Total current population for Germany in 2026 is 83,134,876, a 0.08% decline from 2025.'}, {'title': 'Germany updates: Population growth on the decline', 'url': 'https://www.dw.com/en/germany-updates-population-growth-on-the-decline/live-72979548', 'snippet': "As of the end of 2024, Germany's population stood at just under 83.6 million, an increase of 121,000 compared to the previous year. This marks a slowdown from 2023, when the numbers grew by 338,000.\n\nGermany's population has grown to almost 83.6 million, marking a slowdown from 2023Image: Schoening/imageBROKER/picture alliance\n\nAdvertisement\n\nSkip next section What you need to know\n\n## What you need to know [...] June 20, 2025\n\n## German population growth slows\n\nIn 2024 Germany's population rose by 0.1% which is a drop from the 0.4% growth witnessed the year before, according to preliminary figures released by the Federal Statistical Office on Friday.\n\nAs a result, the population for the EU's largest economy now stands at 83.6 million.\n\nThe figures showed that, as in previous years, more people died than were born in Germany, but the population growth came about due to immigration. [...] The number of foreign nationals living in Germany rose by 2.3% to 12.4 million in 2024, with the largest diaspora being Turkish nationals (1.403 million). The next largest diaspora in Germany, according to the preliminary figures, is the Ukrainian diaspora (1.085 million), followed by nationals from Syria (889,000), Romania (771,000) and Poland (723,000).\n\nPeople walking the streets of Charlottenburg, Berlin"}]}}
# {'executor_id': 'calc', 'tool': 'calculate', 'status': 'ok', 'payload': {'expression': '68000000 + 84000000', 'result': 152000000}}

# %% [markdown]
# ### Final draft answer
#
# The drafter's synthesis of all observations into a direct answer:

# %%
print(out["draft_output"]["text"])
# Out:
# ## Current Population (2024–2025 estimates)
#
# - **France:** ~65 million (approx. 64.9–66.4 million depending on source; e.g., Worldometer/INSEE ~66.4M, Macrotrends ~64.9M)
# - **Germany:** ~83.6 million (Federal Statistical Office/Worldometer estimate for end of 2024)
#
# ## Combined Population
#
# **France + Germany ≈ 149–150 million people**
#
# (Using representative figures: 65,000,000 + 83,600,000 ≈ **148,600,000**)
#
# *Note: Exact figures vary slightly by source and year (2023 vs. 2024 vs. 2025 estimates), but the combined population of France and Germany consistently falls in the range of approximately 148–150 million.*

# %% [markdown]
# ## Try your own task
#
# Swap in any task that plausibly needs one or both tools — the planner decides which
# executor(s) to use.

# %%
custom_task = "What is 17 times the number of member states in the EU?"

custom_out = agent.invoke({"task": custom_task, "context": {}})
print_plan(custom_out["authorized_steps"])
print()
print(custom_out["draft_output"]["text"])
# Out:
# 0. [search] web_search({'query': 'current number of EU member states'}) depends_on=None
# 1. [calc] calculate({'expression': '17 * 27'}) depends_on=None
#
# The EU currently has 27 member states, so 17 × 27 = **459**.

# %% [markdown]
# ## Trace metadata
#
# `invoke_trace` carries a fresh `run_id`, the agent's `variant`, and its `prompt_manifest` — the
# shape `PlannerExecutorBase.to_eval_run_result()` consumes to build an eval-harness `RunResult`
# row from this same output.

# %%
out["invoke_trace"]
# Out:
# {'run_id': '03d0dc00-2564-4e43-a717-fa16a3312656',
#  'variant': 'plan_then_act_demo',
#  'session_label': None,
#  'prompt_manifest': {}}
